# %% [markdown]
# # Summary
#
# Starting point for a supervised learning model for Ookla speed tiles. The data comes from a combination of
# Ookla Open Data speed tests and Statistics Canada information, including 2016 census population data and census boundaries (shapefiles).

# %% [markdown]
# REQUIRED: Loading the features table generated after running the feature_table_generate.py.

# %%
#Loading the pickle file
import bz2
import pickle 

ifile = bz2.BZ2File("../data/Features.pickle",'rb')
features_table = pickle.load(ifile)

# %%
features_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 338872 entries, 0 to 338871
# Data columns (total 42 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Unnamed: 0   338872 non-null  int64
#  1   quadkey      338872 non-null  int64
#  2   geometry     338872 non-null  object
#  3   avg_d_kbps   338872 non-null  float64
#  4   avg_u_kbps   338872 non-null  float64
#  5   tests        338872 non-null  int64
#  6   devices      338872 non-null  int64
#  7   DAUID        338872 non-null  int64
#  8   PRUID        338872 non-null  int64
#  9   PRNAME       338872 non-null  object
#  10  CDUID        338872 non-null  int64
#  11  CDNAME       338872 non-null  object
#  12  CDTYPE       338872 non-null  object
#  13  CCSUID       338872 non-null  int64
#  14  CCSNAME      338872 non-null  object
#  15  CSDUID       338872 non-null  int64
#  16  CSDNAME      338872 non-null  object
#  17  CSDTYPE      338872 non-null  object
#  18  ERUID        338872 non-null  int64
#  19  ERNAME       338872 non-null  object
#  20  SACCODE      338872 non-null  int64
#  21  SACTYPE      338872 non-null  int64
#  22  CMAUID       166387 non-null  float64
#  23  CMAPUID      166387 non-null  float64
#  24  CMANAME      166387 non-null  object
#  25  CMATYPE      166387 non-null  object
#  26  CTUID        130203 non-null  float64
#  27  CTNAME       130203 non-null  float64
#  28  ADAUID       338872 non-null  int64
#  29  das_area     338872 non-null  float64
#  30  tile_area    338872 non-null  float64
#  31  tile_frac    338872 non-null  float64
#  32  das_frac     338872 non-null  float64
#  33  DAPOP        338872 non-null  int64
#  34  POP_DENSITY  338872 non-null  float64
#  35  PCUID        102045 non-null  float64
#  36  PCNAME       102045 non-null  object
#  37  PCTYPE       102045 non-null  float64
#  38  PCPUID       102045 non-null  float64
#  39  PCCLASS      102045 non-null  float64
#  40  avg_d_mbps   338872 non-null  float64
#  41  avg_u_mbps   338872 non-null  float64
# dtypes: float64(17), int64(14), object(11)
# memory usage: 108.6+ MB

# %%
features_table.isna().sum()
# Out:
# Unnamed: 0          0
# quadkey             0
# geometry            0
# avg_d_kbps          0
# avg_u_kbps          0
# tests               0
# devices             0
# DAUID               0
# PRUID               0
# PRNAME              0
# CDUID               0
# CDNAME              0
# CDTYPE              0
# CCSUID              0
# CCSNAME             0
# CSDUID              0
# CSDNAME             0
# CSDTYPE             0
# ERUID               0
# ERNAME              0
# SACCODE             0
# SACTYPE             0
# CMAUID         172485
# CMAPUID        172485
# CMANAME        172485
# CMATYPE        172485
# CTUID          208669
# CTNAME         208669
# ADAUID              0
# das_area            0
# tile_area           0
# tile_frac           0
# das_frac            0
# DAPOP               0
# POP_DENSITY         0
# PCUID          236827
# PCNAME         236827
# PCTYPE         236827
# PCPUID         236827
# PCCLASS        236827
# avg_d_mbps          0
# avg_u_mbps          0
# dtype: int64

# %%
#As we want to wokr with the MBps speed adding a column with MBPS of up and down streams.
features_table["avg_d_mbps"]=features_table["avg_d_kbps"]//1000.0
features_table["avg_u_mbps"]=features_table["avg_u_kbps"]//1000.0
features_table.describe()
#features_table.to_csv("Features.csv")
# Out:
#           Unnamed: 0       quadkey     avg_d_kbps     avg_u_kbps
# count  338872.000000  3.388720e+05  338872.000000  338872.000000  \
# mean   169435.500000  2.699262e+14  103874.745491   40856.405380
# std     97824.064547  4.337019e+13  107993.249061   65208.417261
# min         0.000000  2.333113e+13       1.000000       1.000000
# 25%     84717.750000  2.130033e+14   19770.000000    3725.246132
# 50%    169435.500000  3.022313e+14   62284.333333   12757.062500
# 75%    254153.250000  3.023120e+14  168659.271429   52885.430000
# max    338871.000000  3.033030e+14  933773.000000  914277.000000
#
#                tests        devices         DAUID          PRUID
# count  338872.000000  338872.000000  3.388720e+05  338872.000000  \
# mean       32.430874       9.786102  3.589412e+07      35.625643
# std        86.619264      24.184333  1.373637e+07      13.787237
# min         1.000000       1.000000  1.001016e+07      10.000000
# 25%         1.000000       1.000000  2.467030e+07      24.000000
# 50%         5.000000       2.000000  3.529024e+07      35.000000
# 75%        23.000000       7.000000  4.801018e+07      48.000000
# max      3958.000000    1576.000000  6.208002e+07      62.000000
#
#                CDUID        CCSUID  ...     tile_frac      das_frac
# count  338872.000000  3.388720e+05  ...  3.388720e+05  3.388720e+05  \
# mean     3589.363444  3.589402e+06  ...  8.470142e-01  6.315359e-02
# std      1373.617908  1.373610e+06  ...  2.112869e-01  1.467736e-01
# min      1001.000000  1.001214e+06  ...  1.844074e-07  1.424860e-10
# 25%      2467.000000  2.467045e+06  ...  7.001236e-01  1.624296e-03
# 50%      3529.000000  3.529005e+06  ...  9.994030e-01  6.150156e-03
# 75%      4801.000000  4.801003e+06  ...  1.000000e+00  3.376454e-02
# max      6208.000000  6.208098e+06  ...  1.000000e+00  1.000000e+00
#
#                DAPOP    POP_DENSITY          PCUID         PCTYPE
# count  338872.000000  338872.000000  102045.000000  102045.000000  \
# mean      760.795905     438.453000     672.963614       1.801578
# std       986.384968    1219.806608     372.838832       1.452710
# min         0.000000       0.000000       1.000000       1.000000
# 25%       465.000000       5.733951     352.000000       1.000000
# 50%       565.000000      22.723461     654.000000       1.000000
# 75%       745.000000     189.146266     944.000000       2.000000
# max     22075.000000   96751.104100    1576.000000       6.000000
#
#               PCPUID        PCCLASS     avg_d_mbps     avg_u_mbps
# count  102045.000000  102045.000000  338872.000000  338872.000000
# mean   372644.936763       3.190896     103.376198      40.345009
# std    139329.402717       0.904668     107.993836      65.216073
# min    100046.000000       2.000000       0.000000       0.000000
# 25%    240834.000000       2.000000      19.000000       3.000000
# 50%    350944.000000       4.000000      62.000000      12.000000
# 75%    480252.000000       4.000000     168.000000      52.000000
# max    621439.000000       4.000000     933.000000     914.000000
#
# [8 rows x 31 columns]

# %%
#Finding unique values for each columns
# for i in range(0,38):
#     print("-------Finding unique values in column ----------- "+ features_table.columns[i])
#     print(features_table[features_table.columns[i]].unique())

# %%
import numpy as np 
from pandas import DataFrame
import seaborn as sns
#features_table_realtion = features_table.drop(columns=["quadkey","geometry"])
features_table_realtion = features_table.filter(['avg_d_mbps','avg_u_mbps','tests','devices','POP_DENSITY'], axis=1).head(1000)
sns.heatmap(features_table_realtion, annot=True)

# %%
#Mean and Standard dev for each provience along with total size of location in each provience0) 
Feature_all_downspeed = features_table.groupby("PRNAME")["avg_d_mbps"].agg(['size','mean','std']).reset_index()
Feature_all_downspeed.columns = ["Proviences","Size_Total","Mean_Download_Speed","std_Download_Speed"]
Feature_all_downspeed.head(13)

# %%
Feature_all_upspeed = features_table.groupby("PRNAME")["avg_u_mbps"].agg(['size','mean','std']).reset_index()
Feature_all_upspeed.columns = ["Proviences","Size_Total","Mean_Upload_Speed","STD_Upload_Speed"]
Feature_all_upspeed.head(13)

#TODO: Size total will be used to find the gap between total location having internet vs Total location not meeting the speed criteria the GAP.

frames=[Feature_all_downspeed,Feature_all_upspeed]
result = pd.concat(frames,axis=1)
result = result.T.drop_duplicates().T
result.head(13)

# %%
#Similarly repeating process for internet criteria
#Finding how many locations does not meet the criteria of min up/download speed by provience
Query_up_down_speed = features_table.query('avg_d_mbps < 50 | avg_u_mbps < 10')

#For Download speeed
Query_downspeed = Query_up_down_speed.groupby("PRNAME")["avg_d_mbps"].agg(['size','mean','std',]).reset_index()
Query_downspeed.columns = ["Proviences","Crt_Size_Total","Crt_Mean_Download_Speed","Crt_std_Download_Speed"]
Query_downspeed.head(30)

# %%
#For upload speed
Query_upspeed = Query_up_down_speed.groupby("PRNAME")["avg_u_mbps"].agg(['size','mean','std']).reset_index()
Query_upspeed.columns = ["Proviences","Crt_Size_Total","Crt_Mean_Up_Speed","Crt_std_Up_Speed"]
Query_upspeed.head(30)

# %%
frames_crt=[Query_downspeed,Query_upspeed]
result_crt = pd.concat(frames_crt,axis=1)
result_crt = result_crt.T.drop_duplicates().T
result_crt.head(13)

# %%
#Merging boeth the result tables having all the mean,std,size details for actual and expected criteria
frames_final=[result,result_crt]
result_find_gap = pd.concat(frames_final,axis=1)
result_find_gap = result_find_gap.T.drop_duplicates().T
result_find_gap.head(13)

# %%
#Adding percentage column to find the gap and better understanding
result_find_gap["Percentage_gap"] = (result_find_gap["Crt_Size_Total"]/result_find_gap["Size_Total"])*100
result_find_gap.to_csv("Gap Analysis.csv")
result_find_gap.sort_values(by="Percentage_gap", ascending=False,inplace=True)
result_find_gap.head(13)

import plotly.express as px
fig = px.bar(result_find_gap, x='Proviences',y='Percentage_gap')
fig.show()

# %%
for_visualization_gap = pd.read_csv("../data/Gap_Analysis.csv")
for_visualization_gap.head()
# Out:
#    Unnamed: 0                                         Proviences  Size_Total
# 0           0                                            Alberta       46933  \
# 1           1            British Columbia / Colombie-Britannique       37060
# 2           2                                           Manitoba       20194
# 3           3                  New Brunswick / Nouveau-Brunswick       13229
# 4           4  Newfoundland and Labrador / Terre-Neuve-et-Lab...        6747
#
#    Mean_Download_Speed  std_Download_Speed  Mean_Upload_Speed
# 0            88.960220           99.179564          33.174589  \
# 1           150.566838          124.436208          64.355235
# 2            81.436318           86.908821          31.959493
# 3           141.915715          138.299939          39.408723
# 4           141.556544          120.608244          43.766859
#
#    STD_Upload_Speed  Crt_Size_Total  Crt_Mean_Download_Speed
# 0         51.976972           28645                27.335870  \
# 1         72.662968           11520                30.925174
# 2         59.413703           12260                30.634502
# 3         58.845470            5370                28.741527
# 4         63.201958            2912                56.487294
#
#    Crt_std_Download_Speed  Crt_Mean_Up_Speed  Crt_std_Up_Speed
# 0               29.772997           6.957689          8.556512
# 1               34.779705           9.908247         12.759966
# 2               33.202787           6.107259         11.330834
# 3               38.468404           5.584171         11.586166
# 4               81.856997           5.619849          8.362949

# %%
#Dumping the generated table to pickle file
import bz2
import pickle
ofile = bz2.BZ2File("../data/Gap_Analysis.pickle",'wb')
pickle.dump(for_visualization_gap,ofile)

# %%
ifile = bz2.BZ2File("../data/Gap_Analysis.pickle",'rb')
for_visualization = pickle.load(ifile)

# %%
for_visualization
# Out:
#     Unnamed: 0                                         Proviences  Size_Total
# 0            0                                            Alberta       46933  \
# 1            1            British Columbia / Colombie-Britannique       37060
# 2            2                                           Manitoba       20194
# 3            3                  New Brunswick / Nouveau-Brunswick       13229
# 4            4  Newfoundland and Labrador / Terre-Neuve-et-Lab...        6747
# 5            5  Northwest Territories / Territoires du Nord-Ouest         381
# 6            6                      Nova Scotia / Nouvelle-Écosse       15962
# 7            7                                            Nunavut          87
# 8            8                                            Ontario      108300
# 9            9       Prince Edward Island / Île-du-Prince-Édouard        4358
# 10          10                                    Quebec / Québec       70612
# 11          11                                       Saskatchewan       14539
# 12          12                                              Yukon         470
#
#     Mean_Download_Speed  std_Download_Speed  Mean_Upload_Speed
# 0             88.960220           99.179564          33.174589  \
# 1            150.566838          124.436208          64.355235
# 2             81.436318           86.908821          31.959493
# 3            141.915715          138.299939          39.408723
# 4            141.556544          120.608244          43.766859
# 5             67.425197           52.314110          19.385827
# 6            129.114522          115.591789          46.401704
# 7             15.252874           29.994658           3.540230
# 8             89.650194          101.872474          29.222068
# 9             96.897659          101.607281          42.969940
# 10           107.645613          103.977077          54.966875
# 11            65.838091           73.259276          19.392118
# 12            45.706383           49.146782           8.827660
#
#     STD_Upload_Speed  Crt_Size_Total  Crt_Mean_Download_Speed
# 0          51.976972           28645                27.335870  \
# 1          72.662968           11520                30.925174
# 2          59.413703           12260                30.634502
# 3          58.845470            5370                28.741527
# 4          63.201958            2912                56.487294
# 5          32.127963             188                29.989362
# 6          65.876107            6678                43.063193
# 7           9.317157              83                10.192771
# 8          56.631427           64688                25.320090
# 9          78.797689            2438                34.650943
# 10         79.804898           28832                25.319575
# 11         36.455886            9600                27.183542
# 12         18.491457             332                21.804217
#
#     Crt_std_Download_Speed  Crt_Mean_Up_Speed  Crt_std_Up_Speed
# 0                29.772997           6.957689          8.556512
# 1                34.779705           9.908247         12.759966
# 2                33.202787           6.107259         11.330834
# 3                38.468404           5.584171         11.586166
# 4                81.856997           5.619849          8.362949
# 5                28.431546           7.648936          9.970767
# 6                63.232726           6.681342         10.638982
# 7                 8.200919           2.819277          8.744538
# 8                31.405652           4.632668          7.768830
# 9                50.582110           5.567268          9.595865
# 10               23.588260           8.035239         11.229480
# 11               29.187405           4.675313          6.974041
# 12               24.056471           4.855422          9.106463
